# %%
# ssdn csdn udn

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2026, 1, 10, 16, 43, 20, 743408)

# %%
now.year
# Out:
# 2026

# %%
now.hour
# Out:
# 16

# %%
import numpy as np

# %%
np.array(["2020-03-15", "2020-03-16", "2020-03-17"], dtype="datetime64[h]")
# Out:
# array(['2020-03-15T00', '2020-03-16T00', '2020-03-17T00'],
#       dtype='datetime64[h]')

# %%
np.arange("2026-01-05", "2026-03-24", 7, dtype="datetime64[D]")
# Out:
# array(['2026-01-05', '2026-01-12', '2026-01-19', '2026-01-26',
#        '2026-02-02', '2026-02-09', '2026-02-16', '2026-02-23',
#        '2026-03-02', '2026-03-09', '2026-03-16', '2026-03-23'],
#       dtype='datetime64[D]')

# %%
np.arange("2020", "2026", dtype="datetime64[Y]")
# Out:
# array(['2020', '2021', '2022', '2023', '2024', '2025'],
#       dtype='datetime64[Y]')

# %%
import pandas as pd

# %%
pd.date_range('2026-01-01', periods=7, freq="D")
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                '2026-01-05', '2026-01-06', '2026-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('Jan 01, 2026', periods=7, freq="D")
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04',
#                '2026-01-05', '2026-01-06', '2026-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.to_datetime(['1--2--2026', '3--1--2026'], format="%d--%m--%Y")
# Out:
# DatetimeIndex(['2026-02-01', '2026-01-03'], dtype='datetime64[ns]', freq=None)

# %%
data = np.random.randn(3,2)

# %%
cols = ['A', 'B']

# %%
data
# Out:
# array([[ 0.9969747 , -0.42108718],
#        [ 1.64832732,  1.63760384],
#        [-1.2716956 , -0.1801635 ]])

# %%
cols
# Out:
# ['A', 'B']

# %%
idx = pd.date_range('2026-01-01', periods=3, freq='D')

df = pd.DataFrame(data, index=idx, columns=cols)

# %%
df.index
# Out:
# DatetimeIndex(['2026-01-01', '2026-01-02', '2026-01-03'], dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    A         B
# 2026-01-01  0.996975 -0.421087
# 2026-01-02  1.648327  1.637604
# 2026-01-03 -1.271696 -0.180164

# %%
df.index.max()
# Out:
# Timestamp('2026-01-03 00:00:00')

# %%
df.index.argmax()
# Out:
# np.int64(2)

# %%
df.index.min()
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
df.index.argmin()
# Out:
# np.int64(0)

# %% [markdown]
# ### Time Resampling

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/starbucks.csv")

# %%
df.head()
# Out:
#          Date    Close    Volume
# 0  2015-01-02  38.0061   6906098
# 1  2015-01-05  37.2781  11623796
# 2  2015-01-06  36.9748   7664340
# 3  2015-01-07  37.8848   9732554
# 4  2015-01-08  38.4961  13170548

# %%
df = pd.read_csv("Data/starbucks.csv", parse_dates=["Date"], index_col="Date")

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2015-01-02 to 2018-12-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1006 non-null   float64
#  1   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 23.6 KB

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %% [markdown]
# <table style="display: inline-block">
#     <caption style="text-align: center"><strong>TIME SERIES OFFSET ALIASES</strong></caption>
# <tr><th>ALIAS</th><th>DESCRIPTION</th></tr>
# <tr><td>B</td><td>business day frequency</td></tr>
# <tr><td>C</td><td>custom business day frequency (experimental)</td></tr>
# <tr><td>D</td><td>calendar day frequency</td></tr>
# <tr><td>W</td><td>weekly frequency</td></tr>
# <tr><td>M</td><td>month end frequency</td></tr>
# <tr><td>SM</td><td>semi-month end frequency (15th and end of month)</td></tr>
# <tr><td>BM</td><td>business month end frequency</td></tr>
# <tr><td>CBM</td><td>custom business month end frequency</td></tr>
# <tr><td>MS</td><td>month start frequency</td></tr>
# <tr><td>SMS</td><td>semi-month start frequency (1st and 15th)</td></tr>
# <tr><td>BMS</td><td>business month start frequency</td></tr>
# <tr><td>CBMS</td><td>custom business month start frequency</td></tr>
# <tr><td>Q</td><td>quarter end frequency</td></tr>
# <tr><td></td><td><font color=white>intentionally left blank</font></td></tr></table>
#
# <table style="display: inline-block; margin-left: 40px">
# <caption style="text-align: center"></caption>
# <tr><th>ALIAS</th><th>DESCRIPTION</th></tr>
# <tr><td>BQ</td><td>business quarter endfrequency</td></tr>
# <tr><td>QS</td><td>quarter start frequency</td></tr>
# <tr><td>BQS</td><td>business quarter start frequency</td></tr>
# <tr><td>A</td><td>year end frequency</td></tr>
# <tr><td>BA</td><td>business year end frequency</td></tr>
# <tr><td>AS</td><td>year start frequency</td></tr>
# <tr><td>BAS</td><td>business year start frequency</td></tr>
# <tr><td>BH</td><td>business hour frequency</td></tr>
# <tr><td>H</td><td>hourly frequency</td></tr>
# <tr><td>T, min</td><td>minutely frequency</td></tr>
# <tr><td>S</td><td>secondly frequency</td></tr>
# <tr><td>L, ms</td><td>milliseconds</td></tr>
# <tr><td>U, us</td><td>microseconds</td></tr>
# <tr><td>N</td><td>nanoseconds</td></tr></table>

# %%
df.resample(rule='YE').std()
# # # FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead. df.resample(rule='A').mean()
# Out:
#                Close        Volume
# Date
# 2015-12-31  6.076922  4.093368e+06
# 2016-12-31  1.958114  3.936798e+06
# 2017-12-31  2.415526  4.690972e+06
# 2018-12-31  4.678178  6.465358e+06

# %%
def first_day(entry):
    if len(entry):
        return entry[0]

# %%
df.resample(rule="YE").apply(first_day)
# Out:
# /tmp/ipykernel_10108/710633468.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return entry[0]
#               Close    Volume
# Date
# 2015-12-31  38.0061   6906098
# 2016-12-31  55.0780  13521544
# 2017-12-31  53.1100   7809307
# 2018-12-31  56.3243   7215978

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
# %matplotlib inline
df["Close"].resample("YE").mean().plot.bar()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].resample("M").max().plot.bar(figsize=(16, 6), title="Monthly Max Closing Prices")
# Out:
# /tmp/ipykernel_10108/2089447713.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df["Close"].resample("M").max().plot.bar(figsize=(16, 6), title="Monthly Max Closing Prices")
# <Axes: title={'center': 'Monthly Max Closing Prices'}, xlabel='Date'>

# %% [markdown]
# ### Time Shifting

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/starbucks.csv", index_col="Date", parse_dates=True)

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.tail()
# Out:
#             Close    Volume
# Date
# 2018-12-24  60.56   6323252
# 2018-12-26  63.08  16646238
# 2018-12-27  63.20  11308081
# 2018-12-28  63.39   7712127
# 2018-12-31  64.40   7690183

# %%
df.shift(1).tail()
# Out:
#             Close      Volume
# Date
# 2018-12-24  61.39  23524888.0
# 2018-12-26  60.56   6323252.0
# 2018-12-27  63.08  16646238.0
# 2018-12-28  63.20  11308081.0
# 2018-12-31  63.39   7712127.0

# %%
df.shift(3).tail()
# Out:
#             Close      Volume
# Date
# 2018-12-24  64.06  14390146.0
# 2018-12-26  62.15  20264918.0
# 2018-12-27  61.39  23524888.0
# 2018-12-28  60.56   6323252.0
# 2018-12-31  63.08  16646238.0

# %%
df.shift(-1)
# Out:
#               Close      Volume
# Date
# 2015-01-02  37.2781  11623796.0
# 2015-01-05  36.9748   7664340.0
# 2015-01-06  37.8848   9732554.0
# 2015-01-07  38.4961  13170548.0
# 2015-01-08  37.2361  27556706.0
# ...             ...         ...
# 2018-12-24  63.0800  16646238.0
# 2018-12-26  63.2000  11308081.0
# 2018-12-27  63.3900   7712127.0
# 2018-12-28  64.4000   7690183.0
# 2018-12-31      NaN         NaN
#
# [1006 rows x 2 columns]

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.shift(periods=1, freq="M")
# Out:
# /tmp/ipykernel_10108/1652923178.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.shift(periods=1, freq="M")
#               Close    Volume
# Date
# 2015-01-31  38.0061   6906098
# 2015-01-31  37.2781  11623796
# 2015-01-31  36.9748   7664340
# 2015-01-31  37.8848   9732554
# 2015-01-31  38.4961  13170548
# ...             ...       ...
# 2018-12-31  60.5600   6323252
# 2018-12-31  63.0800  16646238
# 2018-12-31  63.2000  11308081
# 2018-12-31  63.3900   7712127
# 2019-01-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %% [markdown]
# ### Rolling and Expanding

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv("Data/starbucks.csv", parse_dates=True, index_col="Date")

# %%
df.head(30)
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# 2015-01-09  37.2361  27556706
# 2015-01-12  37.4415  10021486
# 2015-01-13  37.7401  11040702
# 2015-01-14  37.5301   9295084
# 2015-01-15  37.1381   8126602
# 2015-01-16  37.6188   9015502
# 2015-01-20  37.9058  10738304
# 2015-01-21  37.9361  10844182
# 2015-01-22  38.6128  23913056
# 2015-01-23  41.1702  38107194
# 2015-01-26  41.1235  14098574
# 2015-01-27  41.2262  10995808
# 2015-01-28  40.8645  11963202
# 2015-01-29  41.5575  12475860
# 2015-01-30  40.8482  10070456
# 2015-02-02  41.0629  13638832
# 2015-02-03  41.4469   9252426
# 2015-02-04  41.5453  11496698
# 2015-02-05  41.9856   7598672
# 2015-02-06  41.6858   7835332
# 2015-02-09  41.6015   6911614
# 2015-02-10  42.7069  12469500
# 2015-02-11  42.5242   6466910
# 2015-02-12  43.0090   7197558
# 2015-02-13  42.8942   6109522

# %%
df["Close"].plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
df.rolling(window=7).mean().head(30)
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07
# 2015-01-16  37.600114  1.260380e+07
# 2015-01-20  37.515786  1.225634e+07
# 2015-01-21  37.615786  9.868837e+06
# 2015-01-22  37.783114  1.185335e+07
# 2015-01-23  38.273129  1.571999e+07
# 2015-01-26  38.786471  1.640620e+07
# 2015-01-27  39.370486  1.681609e+07
# 2015-01-28  39.834157  1.723719e+07
# 2015-01-29  40.355829  1.748541e+07
# 2015-01-30  40.771843  1.737488e+07
# 2015-02-02  41.121857  1.590713e+07
# 2015-02-03  41.161386  1.178502e+07
# 2015-02-04  41.221643  1.141333e+07
# 2015-02-05  41.330129  1.092802e+07
# 2015-02-06  41.447457  1.033833e+07
# ...

# %%
df["Close"].plot(figsize=(12, 5))
df.rolling(window=7).mean()["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].plot(figsize=(12, 5))
df.rolling(window=30).mean()["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close:30DayMean"] = df["Close"].rolling(window=30).mean()

# %%
df.head(10)
# Out:
#               Close    Volume  Close:30DayMean
# Date
# 2015-01-02  38.0061   6906098              NaN
# 2015-01-05  37.2781  11623796              NaN
# 2015-01-06  36.9748   7664340              NaN
# 2015-01-07  37.8848   9732554              NaN
# 2015-01-08  38.4961  13170548              NaN
# 2015-01-09  37.2361  27556706              NaN
# 2015-01-12  37.4415  10021486              NaN
# 2015-01-13  37.7401  11040702              NaN
# 2015-01-14  37.5301   9295084              NaN
# 2015-01-15  37.1381   8126602              NaN

# %%
df[["Close", "Close:30DayMean"]].plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].expanding().mean().plot(figsize=(12, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
df["CloseExpanding"] = df["Close"].expanding().mean()

# %%
df.head(20)
# Out:
#               Close    Volume  Close:30DayMean  CloseExpanding
# Date
# 2015-01-02  38.0061   6906098              NaN       38.006100
# 2015-01-05  37.2781  11623796              NaN       37.642100
# 2015-01-06  36.9748   7664340              NaN       37.419667
# 2015-01-07  37.8848   9732554              NaN       37.535950
# 2015-01-08  38.4961  13170548              NaN       37.727980
# 2015-01-09  37.2361  27556706              NaN       37.646000
# 2015-01-12  37.4415  10021486              NaN       37.616786
# 2015-01-13  37.7401  11040702              NaN       37.632200
# 2015-01-14  37.5301   9295084              NaN       37.620856
# 2015-01-15  37.1381   8126602              NaN       37.572580
# 2015-01-16  37.6188   9015502              NaN       37.576782
# 2015-01-20  37.9058  10738304              NaN       37.604200
# 2015-01-21  37.9361  10844182              NaN       37.629731
# 2015-01-22  38.6128  23913056              NaN       37.699950
# ...

# %% [markdown]
# ### Visualizing

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Volume"].plot();

# %%
title = "TITLE"
xlabel = "X LABEL"
ylabel = "Y LABEL"

# %%
ax = df["Close"].plot(figsize=(16, 7), title=title)
ax.autoscale(axis="y", tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %%
df["Close"].plot(figsize=(15, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"]["2017-01-01":"2017-12-31"]
# Out:
# Date
# 2017-01-03    53.1100
# 2017-01-04    53.7241
# 2017-01-05    54.1750
# 2017-01-06    54.8179
# 2017-01-09    55.8446
#                ...
# 2017-12-22    56.0018
# 2017-12-26    55.8454
# 2017-12-27    55.9724
# 2017-12-28    56.5002
# 2017-12-29    56.1288
# Name: Close, Length: 251, dtype: float64

# %%
df["Close"]["2017-01-01":"2017-12-31"].plot(figsize=(15, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].plot(figsize=(15, 5), xlim=["2017-01-01", "2017-12-31"])
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"]["2017-01-01":"2017-12-31"].plot(figsize=(15, 5), ylim=[0,70])
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"]["2017-01-01":"2017-12-31"].plot(figsize=(15, 5), ylim=[40,70], ls="--", c="red")
# Out:
# <Axes: xlabel='Date'>

# %%
from matplotlib import dates

# %%
ax = df["Close"].plot(figsize=(13, 5), xlim=["2017-01-01", "2017-03-01"], ylim=[50, 60])
ax.set(xlabel="")

ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0)) # specify date range for x axis
ax.xaxis.set_major_formatter(dates.DateFormatter("%d")) # fmt="%a-%B-%d"

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter("\n\n%b"))

ax.yaxis.grid(True)
ax.xaxis.grid(True)
