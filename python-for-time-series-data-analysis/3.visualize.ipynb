# %%
import pandas as pd
# %matplotlib inline
# This line says that Hey notebook i want to visualization within this notebook.

# %%
data_path = "Datas/3.1-df1.csv"

# %%
df1 = pd.read_csv(data_path)

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("Datas/3.2-df2.csv")

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %% [markdown]
# #### see distribution -> Histogram

# %%
df1["A"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1["A"].plot.hist(edgecolor='k')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1["A"].plot.hist(edgecolor='k').autoscale(enable=True, axis="both", tight=True)

# %%
df1["A"].plot.hist(bins=50, edgecolor='k').autoscale(enable=True, axis="both", tight=True)

# %%
df1["A"].plot.hist().grid(True)

# %% [markdown]
# #### bar plots

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# #### line

# %%
df2.plot.line(y="a")
# Out:
# <Axes: >

# %%
df2.plot.line(y="b")
# Out:
# <Axes: >

# %%
df2.plot.line(y="c", figsize=(10, 6))
# Out:
# <Axes: >

# %%
df2.plot.line(y="d", figsize=(10, 6), lw=5)
# Out:
# <Axes: >

# %%
df2.plot.line(y=["a", "c", "d"], figsize=(10, 6), lw=3)
# Out:
# <Axes: >

# %% [markdown]
# #### area

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.3)
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.3, stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# #### scatter

# %%
df1
# Out:
#      Unnamed: 0         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df1.plot.scatter(x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c="C")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c="D", cmap="coolwarm")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s="C")
# Out:
# /home/ibrahim/.local/lib/python3.9/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1["C"])
# Out:
# /home/ibrahim/.local/lib/python3.9/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1["C"]*5, alpha=0.5)
# Out:
# /home/ibrahim/.local/lib/python3.9/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# #### boxplot

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### kde

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### hexagonal size

# %%
import numpy as np

df = pd.DataFrame(np.random.rand(1000, 2), columns=['a', 'b'])

# %%
df.plot.scatter(x='a', y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a', y='b', gridsize=25, cmap="Oranges")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ### Customizing Plots
