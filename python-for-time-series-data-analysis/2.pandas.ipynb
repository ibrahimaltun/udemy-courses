# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series

# %%
labels = ["a", "b", "c"]

# %%
mylist = [10, 20, 30]

# %%
arr = np.array(mylist)

# %%
arr
# Out:
# array([10, 20, 30])

# %%
d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(mylist)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=mylist, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series(data=["Ottoman", "South Africa",
                 "South Korea"], index=[1, 2, 3])

# %%
ser1
# Out:
# 1         Ottoman
# 2    South Africa
# 3     South Korea
# dtype: object

# %%
ser1[1]
# Out:
# 'Ottoman'

# %%
ser2 = pd.Series(data=[5, 6, 7, 8], index=["Morocco",
                 "Turkmenistan", "Kazakistan", "Qatar"])

# %%
ser2
# Out:
# Morocco         5
# Turkmenistan    6
# Kazakistan      7
# Qatar           8
# dtype: int64

# %%
ser1 + ser2
# Out:
# 1               NaN
# 2               NaN
# 3               NaN
# Kazakistan      NaN
# Morocco         NaN
# Qatar           NaN
# Turkmenistan    NaN
# dtype: object

# %% [markdown]
# ### DataFrames

# %%
from numpy.random import randn
np.random.seed(101)

rand_mat = randn(5, 4)
rand_mat
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
df = pd.DataFrame(data=rand_mat, index="A B C D E".split(), columns="W X Y Z".split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #### grab the data from df

# %%
df["W"]
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
type(df["W"])
# Out:
# pandas.core.series.Series

# %%
desired_list = ["X", "Y"]

# %%
df[desired_list]
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# C  0.740122  0.528813
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df[["X", "Y"]]
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# C  0.740122  0.528813
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df.W # this is not recommended
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %% [markdown]
# #### add a new column to exist DataFrame

# %%
df["Q"] = df["W"] + df["Y"]

# %%
df
# Out:
#           W         X         Y         Z         Q
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# #### remove the column

# %%
df.drop("Q", axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z         Q
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop("Q", axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #### rows

# %%
df.drop("C")
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc["A"]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.loc[["A"]]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %% [markdown]
# #### integer location

# %%
df.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[3]
# Out:
# W    0.188695
# X   -0.758872
# Y   -0.933237
# Z    0.955057
# Name: D, dtype: float64

# %%
df.iloc[0:2]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965

# %%
df.loc[["B", "E"]]
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #### subset of the data

# %%
df.loc[['A', "B"]][["Y","Z"]]
# Out:
#           Y         Z
# A  0.907969  0.503826
# B -0.848077  0.605965

# %%
df.loc[['A', "B"], ["Y","Z"]]
# Out:
#           Y         Z
# A  0.907969  0.503826
# B -0.848077  0.605965

# %% [markdown]
# ### Dataframes - Part Two

# %%
df > 0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df["W"] > 0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df["W"] > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df["W"] > 0][["Y"]]
# Out:
#           Y
# A  0.907969
# B -0.848077
# D -0.933237
# E  2.605967

# %%
df[df["W"] > 0][["Y"]].loc["A"]
# Out:
# Y    0.907969
# Name: A, dtype: float64

# %% [markdown]
# #### multiple conditions

# %%
cond1 = df["W"] > 0
cond2 = df["Y"] > 1

# %%
df[cond1 and cond2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12928/2218295925.py in ?()
# ----> 1 df[cond1 and cond2]
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(cond1) & (cond2)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #### reset and set index

# %%
df.reset_index()
# Out:
#   States         W         X         Y         Z
# 0    IST  2.706850  0.628133  0.907969  0.503826
# 1    ANK  0.651118 -0.319318 -0.848077  0.605965
# 2    KON -2.018168  0.740122  0.528813 -0.589001
# 3    ERZ  0.188695 -0.758872 -0.933237  0.955057
# 4    URF  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#                W         X         Y         Z
# States
# IST     2.706850  0.628133  0.907969  0.503826
# ANK     0.651118 -0.319318 -0.848077  0.605965
# KON    -2.018168  0.740122  0.528813 -0.589001
# ERZ     0.188695 -0.758872 -0.933237  0.955057
# URF     0.190794  1.978757  2.605967  0.683509

# %%
new_ind = "IST ANK KON ERZ URF".split()

# %%
new_ind
# Out:
# ['IST', 'ANK', 'KON', 'ERZ', 'URF']

# %%
df["States"] = new_ind

# %%
df
# Out:
#                W         X         Y         Z States
# States
# IST     2.706850  0.628133  0.907969  0.503826    IST
# ANK     0.651118 -0.319318 -0.848077  0.605965    ANK
# KON    -2.018168  0.740122  0.528813 -0.589001    KON
# ERZ     0.188695 -0.758872 -0.933237  0.955057    ERZ
# URF     0.190794  1.978757  2.605967  0.683509    URF

# %%
df.set_index("States", inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# IST     2.706850  0.628133  0.907969  0.503826
# ANK     0.651118 -0.319318 -0.848077  0.605965
# KON    -2.018168  0.740122  0.528813 -0.589001
# ERZ     0.188695 -0.758872 -0.933237  0.955057
# URF     0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #### get df informations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, IST to URF
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       5 non-null      float64
#  1   X       5 non-null      float64
#  2   Y       5 non-null      float64
#  3   Z       5 non-null      float64
# dtypes: float64(4)
# memory usage: 200.0+ bytes

# %%
df.head()
# Out:
#                W         X         Y         Z
# States
# IST     2.706850  0.628133  0.907969  0.503826
# ANK     0.651118 -0.319318 -0.848077  0.605965
# KON    -2.018168  0.740122  0.528813 -0.589001
# ERZ     0.188695 -0.758872 -0.933237  0.955057
# URF     0.190794  1.978757  2.605967  0.683509

# %%
df.dtypes
# Out:
# W    float64
# X    float64
# Y    float64
# Z    float64
# dtype: object

# %%
df.describe()
# Out:
#               W         X         Y         Z
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.343858  0.453764  0.452287  0.431871
# std    1.681131  1.061385  1.454516  0.594708
# min   -2.018168 -0.758872 -0.933237 -0.589001
# 25%    0.188695 -0.319318 -0.848077  0.503826
# 50%    0.190794  0.628133  0.528813  0.605965
# 75%    0.651118  0.740122  0.907969  0.683509
# max    2.706850  1.978757  2.605967  0.955057

# %% [markdown]
# #### several tricks

# %%
df
# Out:
#                W         X         Y         Z
# States
# IST     2.706850  0.628133  0.907969  0.503826
# ANK     0.651118 -0.319318 -0.848077  0.605965
# KON    -2.018168  0.740122  0.528813 -0.589001
# ERZ     0.188695 -0.758872 -0.933237  0.955057
# URF     0.190794  1.978757  2.605967  0.683509

# %%
ser_w = df["W"] > 0

# %%
ser_w.value_counts()
# Out:
# W
# True     4
# False    1
# Name: count, dtype: int64

# %%
sum(ser_w)
# Out:
# 4

# %%
len(ser_w)
# Out:
# 5

# %% [markdown]
# ### Missing Data
